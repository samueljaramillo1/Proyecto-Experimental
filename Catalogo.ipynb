# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # Obtener la gráfica del espectro del sol

# %%
longitudes_fe = [6251.286, 6252.565, 6253.834, 6254.253, 6255.952,
                 6256.367, 6267.845, 6270.231, 6271.28, 6271.495,
                 6276.93, 6280.622, 6284.001, 6290.532, 6290.974,
                 6293.933, 6297.799, 6301.508, 6301.845, 6302.499,
                 6303.461, 6305.314, 6306.218, 6307.854, 6311.504,
                 6315.314, 6315.412, 6315.814, 6318.027, 6322.694,
                 6330.852, 6331.953, 6335.337, 6336.830, 6338.880,
                 6339.975, 6344.155, 6351.287]

longitudes_o = [6276.59, 6276.633, 6276.81, 6276.93, 6277.312,
                6277.419, 6277.470, 6277.525, 6277.638, 6277.785,
                6278.073, 6278.126, 6278.374, 6278.878, 6279.101,
                6279.233, 6279.506, 6279.896, 6280.393, 6280.89, 
                6281.178, 6281.781, 6281.956, 6282.726, 6283.796,
                6284.536, 6287.749, 6289.398, 6290.221, 6292.162,
                6292.958, 6295.178, 6295.960, 6298.457, 6299.228,
                6302.000, 6302.764, 6305.810, 6306.565, 6309.886,
                6310.636, 6314.235, 6314.977, 6318.853, 6319.591,
                6323.750, 6324.479, 6328.913, 6329.636, 6334.358,
                6335.072]


reduced_width_fe = [0.3, 18.7, 2.7, 15.0, 2.7, 
                    12.9, 0.8, 8.0, 3.0, 0.5, 
                    1.3, 8.3, 0.1, 1.0, 10.5, 
                    1.9, 11.0, 19.4, 0.2, 13.0, 
                    0.6, 0.8, 0.2, 0.8, 3.6, 
                    8.2, 2.5, 5.2, 15.7, 11.9, 
                    5.0, 1.7, 16.1, 18.5, 6.6, 
                    0.2, 8.8, 0.4]

reduced_width_o = [3.8, 3.8, 3.3, 1.3, 4.1, 
                   1.8, 1.6, 1.0, 3.0, 1.3,
                   4.9, 4.0, 0.6, 3.5, 4.3, 
                   0.6, 0.3, 3.7, 4.1, 0.2, 
                   3.2, 0.1, 3.5, 3.5, 1.9, 
                   1.0, 2.1, 2.4, 3.3, 3.0, 
                   4.0, 3.6, 3.8, 3.5, 4.8, 
                   3.6, 3.3, 2.8, 2.7, 3.5, 
                   1.9, 1.6, 1.7, 0.7, 0.7, 
                   0.7, 0.6, 0.4, 0.4, 0.4, 
                   0.6]

# %%
error_fe = [reduced_width_fe,[0]*len(reduced_width_fe)]
error_o = [reduced_width_o,[0]*len(reduced_width_o)]

error_fe_abajo = [[0]*len(reduced_width_fe),reduced_width_fe]
error_o_abajo = [[0]*len(reduced_width_o),reduced_width_o]

# %%
fig = plt.figure(figsize=(15,5),dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.errorbar(longitudes_fe, reduced_width_fe, yerr = error_fe, elinewidth = 1, fmt='o', ms=1, label = 'Fe', color = 'r')
ax.errorbar(longitudes_o, reduced_width_o, yerr = error_o, elinewidth = 1, fmt='o', ms=1, label = 'O', color = 'b')

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_xticks(np.arange(6250, 6351, 5))
ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_xlabel(r'Longitud de onda (Armstongs)')
ax.set_ylabel('Intensidad (Unidades arbitrarias)')
ax.legend()
ax.set_title('Espectro del sol entre 6250 y 6350 Armstrongs')

plt.show()

fig.savefig('Espectro_sol.png')

# %%
fig = plt.figure(figsize=(30,5),dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.errorbar(longitudes_fe, -1*np.array(reduced_width_fe), yerr = error_fe_abajo, elinewidth = 1, fmt='o', ms=1, label = 'Fe', color = 'r')
ax.errorbar(longitudes_o, -1*np.array(reduced_width_o), yerr = error_o_abajo, elinewidth = 1, fmt='o', ms=1, label = 'O', color = 'b')

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_xticks(np.arange(6250, 6351, 2.5))
ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_xlabel(r'Longitud de onda (Armstongs)')
ax.set_ylabel('Intensidad (Unidades arbitrarias)')
ax.legend()
ax.set_title('Espectro del sol entre 6250 y 6350 Armstrongs')

plt.show()

fig.savefig('Espectro_sol_abajo.png')

# %% [markdown]
# ## Ensayo Toma 1

# %% [markdown]
# #### $x_1 = 1$, $y_1 = 195$, $x_2 = 1530$, $y_2 = 188$, $\theta = arctan(\frac{195 - 188}{1530}) = 0.26213^o$. Ancho desde 195 hasta 198

# %%
def func(x, a, b, c):
    return a*(x**2) + b*x + c

def centro_masa(pixeles, intensidades):
    producto = 0
    suma_intensidades = 0
    for i in range(len(pixeles)):
        producto += pixeles[i]*(35000 - intensidades[i])
        suma_intensidades += (35000 - intensidades[i])
    
    return producto/suma_intensidades

def centroide(pixeles, intensidades):
    popt, pcov = curve_fit(func, pixeles, intensidades)
    a = popt[0]
    b = popt[1]
    return -b/(2*a)

# %%
pixeles_fe_1 = [centroide([415,416,417,418,419],[24359,21520,20116,21693,24773]), centroide([754,755,756,757,758],[24474,22429,21611,21990,24056]), centroide([851,852,853,854,855],[30481,29915,29535,29648,30300]),
              centroide([979,980,981,982],[21790,19469,19512,21978]), centroide([1100,1101,1103,1104],[20920,17991,15972,18000]), centroide([1133,1134,1135,1136,1138,1139],[23025,20001,18515,19182,25281,27875])]
long_fe = [6280.622, 6290.974 ,6293.933, 
           6297.799 , 6301.508, 6302.499]

pixeles_o_1 = [centroide([285,286,287],[24579,23674,25430]), centroide([307,308,309,310],[26732,23624,22030,23230]), centroide([332,334,335,336],[21117,16756,17837,21365]), 
             centroide([358,360,361],[25251,23464,25170]), centroide([366,367,368,369],[25222,22776,26390,27208]), centroide([392,393,394],[25101,23418,24340]), centroide([408,409,410,411],[26409,23306,22921,25796]), 
             centroide([434,435,437],[26648,24646,28816]), centroide([459,460,461,463],[28050,25171,24560,29884]), centroide([484,485,486,487,488,489],[26562,24662,23568,24889,26652,28246]), centroide([519,521,522],[29965,27189,28516]), 
             centroide([544,545,546],[30457,29708,30075]), centroide([648,650,651,652],[29701,27844,28043,29917]), centroide([703,705,706],[29205,26759,29146]), centroide([730,731,732,733,734],[27982,25438,24956,27493,30203]), 
             centroide([794,795,796,797],[26884,24606,25372,28125]), centroide([819,820,821,822,824],[27847,25849,23456,23937,29942]), centroide([892,893,894,896],[29498,27046,24366,27727]), centroide([918,919,920,921,922],[28671,25476,23202,24636,28185]), 
             centroide([1000,1001,1002,1003,1004],[28787,25874,23957,25130,28307]), centroide([1026,1027,1028,1029],[26623,23189,22483,25606]), centroide([1117,1118,1119,1120],[28199,25622,24898,27030]), centroide([1142,1143,1144,1145],[28250,25727,24154,26149])]
long_o = [6276.59, 6277.312, 6278.073, 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6282.726, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]
# Out:
# /Users/samuel/Library/Python/3.11/lib/python/site-packages/scipy/optimize/_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
"""
pixeles_fe_1 = [centro_masa([415,416,417,418,419],[24359,21520,20116,21693,24773]), centro_masa([754,755,756,757,758],[24474,22429,21611,21990,24056]), 
              centro_masa([979,980,981,982],[21790,19469,19512,21978]), centro_masa([1100,1101,1103,1104],[20920,17991,15972,18000])]
long_fe = [6280.622, 6290.974 , 
           6297.799 , 6301.508]

pixeles_o_1 = [centro_masa([307,308,309,310],[26732,23624,22030,23230]), 
             centro_masa([358,360,361],[25251,23464,25170]), centro_masa([366,367,368,369],[25222,22776,26390,27208]), centro_masa([392,393,394],[25101,23418,24340]), centro_masa([408,409,410,411],[26409,23306,22921,25796]), 
             centro_masa([434,435,437],[26648,24646,28816]), centro_masa([459,460,461,463],[28050,25171,24560,29884]),  centro_masa([519,521,522],[29965,27189,28516]), 
             centro_masa([544,545,546],[30457,29708,30075]), centro_masa([648,650,651,652],[29701,27844,28043,29917]), centro_masa([703,705,706],[29205,26759,29146]), centro_masa([730,731,732,733,734],[27982,25438,24956,27493,30203]), 
             centro_masa([794,795,796,797],[26884,24606,25372,28125]), centro_masa([918,919,920,921,922],[28671,25476,23202,24636,28185]), 
             centro_masa([1000,1001,1002,1003,1004],[28787,25874,23957,25130,28307]), centro_masa([1026,1027,1028,1029],[26623,23189,22483,25606]), centro_masa([1117,1118,1119,1120],[28199,25622,24898,27030]), centro_masa([1142,1143,1144,1145],[28250,25727,24154,26149])]
long_o = [6277.312, 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]
"""
# Out:
# '\npixeles_fe_1 = [centro_masa([415,416,417,418,419],[24359,21520,20116,21693,24773]), centro_masa([754,755,756,757,758],[24474,22429,21611,21990,24056]), \n              centro_masa([979,980,981,982],[21790,19469,19512,21978]), centro_masa([1100,1101,1103,1104],[20920,17991,15972,18000])]\nlong_fe = [6280.622, 6290.974 , \n           6297.799 , 6301.508]\n\npixeles_o_1 = [centro_masa([307,308,309,310],[26732,23624,22030,23230]), \n             centro_masa([358,360,361],[25251,23464,25170]), centro_masa([366,367,368,369],[25222,22776,26390,27208]), centro_masa([392,393,394],[25101,23418,24340]), centro_masa([408,409,410,411],[26409,23306,22921,25796]), \n             centro_masa([434,435,437],[26648,24646,28816]), centro_masa([459,460,461,463],[28050,25171,24560,29884]),  centro_masa([519,521,522],[29965,27189,28516]), \n             centro_masa([544,545,546],[30457,29708,30075]), centro_masa([648,650,651,652],[29701,27844,28043,29917]), centro_masa([703,705,706],[29205,26759,29146])
# ...

# %%
'''
pixeles_fe_1 = [centroide([415,416,417,418,419],[24359,21520,20116,21693,24773]), centroide([754,755,756,757,758],[24474,22429,21611,21990,24056]), 
              centroide([979,980,981,982],[21790,19469,19512,21978]), centroide([1100,1101,1103,1104],[20920,17991,15972,18000])]
long_fe = [6280.622, 6290.974 , 
           6297.799 , 6301.508]

pixeles_o_1 = [centroide([307,308,309,310],[26732,23624,22030,23230]), 
             centroide([358,360,361],[25251,23464,25170]), centroide([366,367,368,369],[25222,22776,26390,27208]), centroide([392,393,394],[25101,23418,24340]), centroide([408,409,410,411],[26409,23306,22921,25796]), 
             centroide([434,435,437],[26648,24646,28816]), centroide([459,460,461,463],[28050,25171,24560,29884]),  centroide([519,521,522],[29965,27189,28516]), 
             centroide([544,545,546],[30457,29708,30075]), centroide([648,650,651,652],[29701,27844,28043,29917]), centroide([703,705,706],[29205,26759,29146]), centroide([730,731,732,733,734],[27982,25438,24956,27493,30203]), 
             centroide([794,795,796,797],[26884,24606,25372,28125]), centroide([918,919,920,921,922],[28671,25476,23202,24636,28185]), 
             centroide([1000,1001,1002,1003,1004],[28787,25874,23957,25130,28307]), centroide([1026,1027,1028,1029],[26623,23189,22483,25606]), centroide([1117,1118,1119,1120],[28199,25622,24898,27030]), centroide([1142,1143,1144,1145],[28250,25727,24154,26149])]
long_o = [6277.312, 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]
'''
# Out:
# '\npixeles_fe_1 = [centroide([415,416,417,418,419],[24359,21520,20116,21693,24773]), centroide([754,755,756,757,758],[24474,22429,21611,21990,24056]), \n              centroide([979,980,981,982],[21790,19469,19512,21978]), centroide([1100,1101,1103,1104],[20920,17991,15972,18000])]\nlong_fe = [6280.622, 6290.974 , \n           6297.799 , 6301.508]\n\npixeles_o_1 = [centroide([307,308,309,310],[26732,23624,22030,23230]), \n             centroide([358,360,361],[25251,23464,25170]), centroide([366,367,368,369],[25222,22776,26390,27208]), centroide([392,393,394],[25101,23418,24340]), centroide([408,409,410,411],[26409,23306,22921,25796]), \n             centroide([434,435,437],[26648,24646,28816]), centroide([459,460,461,463],[28050,25171,24560,29884]),  centroide([519,521,522],[29965,27189,28516]), \n             centroide([544,545,546],[30457,29708,30075]), centroide([648,650,651,652],[29701,27844,28043,29917]), centroide([703,705,706],[29205,26759,29146]), centroide([730,731,732,733,7
# ...

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_1, long_o, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_1, long_fe, marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 1')

plt.show()

fig.savefig('Calibre_1.png')

# %% [markdown]
# ### Funciones analisis error

# %%
def error_func(x, s_a, s_b, s_c):
    sigma_a = np.sqrt(s_a)
    sigma_b = np.sqrt(s_b)
    sigma_c = np.sqrt(s_c)
    return np.sqrt((sigma_a*x**2)**2 + (x*sigma_b)**2 + sigma_c**2)


def error_vel(velocidades, sigmas_dlambda, lambdas_i):
    c = 300000000
    return (c/lambdas_i)*sigmas_dlambda

def error_vel_promedio(N, sigmas: list):
    suma = 0
    for i in range(len(sigmas)):
        suma += sigmas[i]**2
    return np.sqrt(suma)/N

def limpia(lista_diferencia, lista_longitudes, lista_pixeles, min, max):
    a = lista_diferencia*300000000/np.array(lista_longitudes)
    b = np.array(lista_longitudes)
    c = np.array(lista_pixeles)

    filtro_1 = a < max
    a = a[filtro_1]
    lista_diferencia = lista_diferencia[filtro_1]
    b = b[filtro_1]
    c = c[filtro_1]

    filtro_2 = a > min
    a = a[filtro_2]
    lista_diferencia = lista_diferencia[filtro_2]
    b = b[filtro_2]
    c = c[filtro_2]

    return lista_diferencia, b, c

# %%
popt_1, pcov_1 = curve_fit(func, pixeles_o_1, long_o)


longitudes_o_funcion_1 = func(np.array(pixeles_o_1),popt_1[0],popt_1[1],popt_1[2])


diferencia_longitudes_o_1 = longitudes_o_funcion_1 - np.array(long_o)

diferencia_longitudes_o_1, long_o, pixeles_o_1 = limpia(diferencia_longitudes_o_1,long_o,pixeles_o_1,-200,200)


popt_1, pcov_1 = curve_fit(func, pixeles_o_1, long_o)

longitudes_fe_funcion_1 = func(np.array(pixeles_fe_1),popt_1[0],popt_1[1],popt_1[2])
diferencia_longitudes_fe_1 = longitudes_fe_funcion_1 - np.array(long_fe)

# %%
error_o_1 = error_func(np.array(pixeles_o_1),pcov_1[0][0],pcov_1[1][1],pcov_1[2][2])
error_fe_1 = error_func(np.array(pixeles_fe_1),pcov_1[0][0],pcov_1[1][1],pcov_1[2][2])

# %%
""""
popt, pcov = curve_fit(func, x_fit, y_fit)

longitudes_fe_experimentales = func(np.array(pixeles_fe),popt[0],popt[1],popt[2])
longitudes_o_funcion = func(np.array(pixeles_o),popt[0],popt[1],popt[2])

diferencia_longitudes_fe = longitudes_fe_experimentales - np.array(long_fe)
diferencia_longitudes_o = longitudes_o_funcion - np.array(long_o)
"""
# Out:
# '"\npopt, pcov = curve_fit(func, x_fit, y_fit)\n\nlongitudes_fe_experimentales = func(np.array(pixeles_fe),popt[0],popt[1],popt[2])\nlongitudes_o_funcion = func(np.array(pixeles_o),popt[0],popt[1],popt[2])\n\ndiferencia_longitudes_fe = longitudes_fe_experimentales - np.array(long_fe)\ndiferencia_longitudes_o = longitudes_o_funcion - np.array(long_o)\n'

# %% [markdown]
# ### Resultado de velocidad toma 1

# %%
velocidades = (diferencia_longitudes_fe_1*300000000)/(np.array(long_fe))
error_velocidades_1 = error_vel(velocidades,error_fe_1,np.array(long_fe))

velocidad = np.mean(velocidades)
error_velocidad_1 = error_vel_promedio(len(error_velocidades_1),error_velocidades_1)
print(velocidad, error_velocidad_1)
# Out:
# -73.31905648159416 300.5102652143614

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_1, (diferencia_longitudes_o_1*300000000)/np.array(long_o), marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_1, (diferencia_longitudes_fe_1*300000000)/(np.array(long_fe)), marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

#ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 1')

plt.show()

fig.savefig('Shift_1.png')

# %% [markdown]
# # Toma 2

# %% [markdown]
# ### (193,187), $\theta = 0.22469$ ancho = 192 a 196

# %%
'''
pixeles_fe_2 = np.flip(np.array([centro_masa([1136,1137,1138],[18724,18484,20980]), centro_masa([1103,1104,1105],[16495,15438,16728]),centro_masa([981,982,983],[20048,18551,20693]),
                centro_masa([853,854,855,856,857],[30428,29965,29759,30401,31032]),centro_masa([756,757,758],[23670,21667,22049]),centro_masa([417,418,419],[22567,20573,20742])]))

long_fe_2 = [6280.622, 6290.974 ,6293.933, 
           6297.799 , 6301.508, 6302.499]
'''
pixeles_fe_2 = np.flip(np.array([centro_masa([1136,1137,1138],[18724,18484,20980]), centro_masa([1103,1104,1105],[16495,15438,16728]),centro_masa([981,982,983],[20048,18551,20693]),
                centro_masa([853,854,855,856,857],[30428,29965,29759,30401,31032]),centro_masa([417,418,419],[22567,20573,20742])]))

long_fe_2 = [6280.622,6293.933, 
           6297.799 , 6301.508, 6302.499]


pixeles_o_2 = np.flip(np.array([centroide([1144,1145,1146],[27470,25418,25825]),centroide([1119,1120,1121],[27442,25624,26262]),centroide([1028,1029,1030],[24865,23379,24923]),
               centroide([1002,1003,1004,1005],[27676,25332,24943,27799]),centroide([895,896,897],[26015,25145,27426]),centroide([822,823,824],[25546,24563,27129]),
               centroide([796,797,798],[26605,26238,28672]),centroide([732,733,734],[27338,25944,27567]),centroide([705,706,707],[28564,27663,28858]),centroide([651,652,653],[29100,28250,29559]),
               centroide([521,522,523],[29306,27968,28284]),centroide([486,487,488],[26043,24583,24918]),centroide([461,462,463],[27019,25471,27041]),
               centroide([410,411,412],[25181,23425,25829]),
               centroide([360,361,362],[27077,25174,25665]),centroide([334,335,336],[21315,18819,19376])]))

long_o_2 = [6278.073, 
          6278.878,  6280.393, 
           6281.956, 6282.726, 6283.796, 
          6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 
            6298.457, 6299.228, 6302.000, 6302.764]

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_2, long_o_2, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_2, long_fe_2, marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 2')

plt.show()

fig.savefig('Calibre_2.png')

# %%
popt_2, pcov_2 = curve_fit(func, pixeles_o_2, long_o_2)


longitudes_o_funcion_2 = func(np.array(pixeles_o_2),popt_2[0],popt_2[1],popt_2[2])

diferencia_longitudes_o_2 = longitudes_o_funcion_2 - np.array(long_o_2)


diferencia_longitudes_o_2, long_o_2, pixeles_o_2 = limpia(diferencia_longitudes_o_2,long_o_2,pixeles_o_2,-100,100)

popt_2, pcov_2 = curve_fit(func, pixeles_o_2, long_o_2)

longitudes_fe_funcion_2 = func(np.array(pixeles_fe_2),popt_2[0],popt_2[1],popt_2[2])
diferencia_longitudes_fe_2 = longitudes_fe_funcion_2 - np.array(long_fe_2)

# %%
error_fe_2 = error_func(np.array(pixeles_fe_2),pcov_2[0][0],pcov_2[1][1],pcov_2[2][2])
error_o_2 = error_func(np.array(pixeles_o_2),pcov_2[0][0],pcov_2[1][1],pcov_2[2][2])

# %% [markdown]
# ### Resultado velocidad toma 2

# %%
velocidades_2 = (diferencia_longitudes_fe_2*300000000)/(np.array(long_fe_2))
error_velocidades_2 = error_vel(velocidades_2,error_fe_2,np.array(long_fe_2))

velocidad_2 = np.mean(np.array([velocidades_2[0],velocidades_2[2], velocidades_2[1]]))
error_velocidad_2 = error_vel_promedio(len(error_velocidades_2),error_velocidades_2)
print(velocidad_2, error_velocidad_2)
# Out:
# -107.68664331786768 268.2436124342804

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_2, (diferencia_longitudes_o_2*300000000)/np.array(long_o_2), marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_2, (diferencia_longitudes_fe_2*300000000)/(np.array(long_fe_2)), marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

#ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 2')

plt.show()

fig.savefig('Shift_2.png')

# %% [markdown]
# # Toma 3

# %% [markdown]
# ### $\theta = 0.224688$ ancho = 192 a 195

# %%
'''
pixeles_fe_3 = [centroide([417,418,419],[22572,20569,20827]),centroide([756,757,758],[23343,21513,21886]),centroide([854,855,856],[29810,29757,30039]),
                centroide([981,982,983],[20020,18944,20808]),centroide([1103,1104,1105],[16359,15550,16775]),centroide([1135,1136,1137,1138],[20835,18683,18565,20692])]
long_fe_3 = [6280.622, 6290.974 ,6293.933, 
           6297.799 , 6301.508, 6302.499]
'''
pixeles_o_3 = [centroide([334,335,336],[22446,20497,2919]),centroide([360,361,362],[27304,25939,26614]),centroide([367,368,369,370],[27582,25301,25126,27562]),centroide([393,394,395],[26780,25415,25922]),centroide([410,411,412],[25962,24747,26583]),centroide([435,436,437],[28662,26787,27031]),
               centroide([461,462,463],[27685,26572,27942]),centroide([486,487,488],[265417,25369,25656]),centroide([521,522,523],[29464,28737,29159]),centroide([546,547,548],[30587,30382,31198]),
               centroide([651,652,653],[29858,29282,30314]),centroide([705,706,707],[28972,28338,29464]),centroide([732,733,734],[27816,26830,28122]),centroide([795,796,797,798],[29160,27071,26965,28933]),
               centroide([822,823,824],[26239,25690,27944]),centroide([895,896,897],[26841,26337,28340]),centroide([920,921,922],[28057,25916,26381]),centroide([1003,1004,1005],[26232,26258,28650]),
               centroide([1028,1029,1030],[28198,24612,26381]),centroide([1119,1120,1121],[27403,26268,27085]),centroide([1144,1145,1146],[27337,25963,26646])]

long_o_3 = [6278.073, 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6282.726, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

# %%
pixeles_fe_3 = [centroide([417,418,419],[22572,20569,20827]),centroide([854,855,856],[29810,29757,30039]),
                centroide([981,982,983],[20020,18944,20808]),centroide([1103,1104,1105],[16359,15550,16775]),centroide([1135,1136,1137,1138],[20835,18683,18565,20692])]
long_fe_3 = [6280.622,6293.933, 
           6297.799 , 6301.508, 6302.499]

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_3, long_o_3, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_3, long_fe_3, marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 3')

plt.show()

fig.savefig('Calibre_3.png')

# %%
popt_3, pcov_3 = curve_fit(func, pixeles_o_3, long_o_3)


longitudes_o_funcion_3 = func(np.array(pixeles_o_3),popt_3[0],popt_3[1],popt_3[2])

diferencia_longitudes_o_3 = longitudes_o_funcion_3 - np.array(long_o_3)

diferencia_longitudes_o_3, long_o_3, pixeles_o_3 = limpia(diferencia_longitudes_o_3,long_o_3,pixeles_o_3,-200,200)


popt_3, pcov_3 = curve_fit(func, pixeles_o_3, long_o_3)

longitudes_fe_funcion_3 = func(np.array(pixeles_fe_3),popt_3[0],popt_3[1],popt_3[2])
diferencia_longitudes_fe_3 = longitudes_fe_funcion_3 - np.array(long_fe_3)

# %%
error_fe_3 = error_func(np.array(pixeles_fe_3),pcov_3[0][0],pcov_3[1][1],pcov_3[2][2])
error_o_3 = error_func(np.array(pixeles_o_3),pcov_3[0][0],pcov_3[1][1],pcov_3[2][2])

# %% [markdown]
# ### Resultado velocidad toma 3

# %%
velocidades_3 = (diferencia_longitudes_fe_3*300000000)/(np.array(long_fe_3))
error_velocidades_3 = error_vel(velocidades_3,error_fe_3,np.array(long_fe_3))

velocidad_3 = np.mean(velocidades_3)
error_velocidad_3 = error_vel_promedio(len(error_velocidades_3),error_velocidades_3)
print(velocidad_3, error_velocidad_3)
# Out:
# 47.319776362109586 268.7385093262246

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_3, (diferencia_longitudes_o_3*300000000)/np.array(long_o_3), marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_3, (diferencia_longitudes_fe_3*300000000)/(np.array(long_fe_3)), marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

#ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 3')

plt.show()

fig.savefig('Shift_3.png')

# %% [markdown]
# # Toma 4

# %% [markdown]
# ### $\theta = 0.262135$ ancho (191,195)

# %%
pixeles_fe_4 = [centroide([417,418,419],[23024,20896,20762]),centroide([854,855,856],[29810,29636,30128]),centroide([980,982,983],[23111,19266,20634]),centroide([1103,1104,1105],[16815,15773,16840]),centroide([1135,1137,1138],[21431,18578,20428])]

long_fe_4 = [6280.622 ,6293.933, 
           6297.799 , 6301.508, 6302.499]

'''

pixeles_fe_4 = [centroide([417,418,419],[23024,20896,20762]),centroide([1103,1104,1105],[16815,15773,16840]),centroide([1135,1137,1138],[21431,18578,20428])]

long_fe_4 = [6280.622 , 6301.508, 6302.499]
'''
           

pixeles_o_4 = [centroide([334,335,336],[23688,21714,21746]),centroide([360,361,362],[28301,26841,26798]),centroide([368,369,370],[26370,25776,27693]),centroide([394,395,396],[26199,26234,28298]),centroide([410,411,412],[26670,25250,26468]),centroide([435,437,438],[29174,27176,28887]),centroide([461,462,463],[28461,27055,27914]),centroide([486,487,488],[26764,25742,25775]),centroide([521,522,523],[29928,28958,29208]),centroide([545,546,547],[31052,30488,30421]),centroide([651,652,653],[29673,29079,29654]),centroide([705,706,707],[29141,28423,28925]),centroide([732,733,735],[28283,27139,29972]),centroide([796,797,798],[27779,27193,28887]),centroide([822,823,824],[26643,26089,27879]),centroide([895,896,897],[27354,26604,28094]),centroide([920,921,922],[28151,26357,26327]),centroide([1003,1004,1005],[26829,26626,28576]),centroide([1028,1029,1030],[26590,25262,26372]),centroide([1119,1120,1121],[28083,26983,27487]),centroide([1144,1145,1146],[28038,26816,27005])]
long_o_4 = [6278.073, 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6282.726, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]
'''
pixeles_o_4 = [centroide([360,361,362],[28301,26841,26798]),centroide([368,369,370],[26370,25776,27693]),centroide([394,395,396],[26199,26234,28298]),centroide([410,411,412],[26670,25250,26468]),centroide([435,437,438],[29174,27176,28887]),centroide([461,462,463],[28461,27055,27914]),centroide([486,487,488],[26764,25742,25775]),centroide([521,522,523],[29928,28958,29208]),centroide([545,546,547],[31052,30488,30421]),centroide([651,652,653],[29673,29079,29654]),centroide([705,706,707],[29141,28423,28925]),centroide([732,733,735],[28283,27139,29972]),centroide([796,797,798],[27779,27193,28887]),centroide([822,823,824],[26643,26089,27879]),centroide([895,896,897],[27354,26604,28094]),centroide([920,921,922],[28151,26357,26327]),centroide([1003,1004,1005],[26829,26626,28576]),centroide([1028,1029,1030],[26590,25262,26372]),centroide([1119,1120,1121],[28083,26983,27487]),centroide([1144,1145,1146],[28038,26816,27005])]
long_o_4 = [ 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6282.726, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]
'''
# Out:
# '\npixeles_o_4 = [centroide([360,361,362],[28301,26841,26798]),centroide([368,369,370],[26370,25776,27693]),centroide([394,395,396],[26199,26234,28298]),centroide([410,411,412],[26670,25250,26468]),centroide([435,437,438],[29174,27176,28887]),centroide([461,462,463],[28461,27055,27914]),centroide([486,487,488],[26764,25742,25775]),centroide([521,522,523],[29928,28958,29208]),centroide([545,546,547],[31052,30488,30421]),centroide([651,652,653],[29673,29079,29654]),centroide([705,706,707],[29141,28423,28925]),centroide([732,733,735],[28283,27139,29972]),centroide([796,797,798],[27779,27193,28887]),centroide([822,823,824],[26643,26089,27879]),centroide([895,896,897],[27354,26604,28094]),centroide([920,921,922],[28151,26357,26327]),centroide([1003,1004,1005],[26829,26626,28576]),centroide([1028,1029,1030],[26590,25262,26372]),centroide([1119,1120,1121],[28083,26983,27487]),centroide([1144,1145,1146],[28038,26816,27005])]\nlong_o_4 = [ \n          6278.878, 6279.101, 6279.896, 6280.393, \
# ...

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_4, long_o_4, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_4, long_fe_4, marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 4')

plt.show()

fig.savefig('Calibre_4.png')

# %%
popt_4, pcov_4 = curve_fit(func, pixeles_o_4, long_o_4)




longitudes_o_funcion_4 = func(np.array(pixeles_o_4),popt_4[0],popt_4[1],popt_4[2])





diferencia_longitudes_o_4 = longitudes_o_funcion_4 - np.array(long_o_4)

diferencia_longitudes_o_4, long_o_4, pixeles_o_4 = limpia(diferencia_longitudes_o_4,long_o_4,pixeles_o_4,-200,200)

popt_4, pcov_4 = curve_fit(func, pixeles_o_4, long_o_4)

longitudes_fe_funcion_4 = func(np.array(pixeles_fe_4),popt_4[0],popt_4[1],popt_4[2])
diferencia_longitudes_fe_4 = longitudes_fe_funcion_4 - np.array(long_fe_4)

# %%
error_fe_4 = error_func(np.array(pixeles_fe_4),pcov_4[0][0],pcov_4[1][1],pcov_4[2][2])
error_o_4 = error_func(np.array(pixeles_o_4),pcov_4[0][0],pcov_4[1][1],pcov_4[2][2])

# %% [markdown]
# ### Resultados velocidad toma 4

# %%
velocidades_4 = (diferencia_longitudes_fe_4*300000000)/(np.array(long_fe_4))
error_velocidades_4 = error_vel(velocidades_4,error_fe_4,np.array(long_fe_4))

velocidad_4 = np.mean(velocidades_4)
error_velocidad_4 = error_vel_promedio(len(error_velocidades_4),error_velocidades_4)
print(velocidad_4, error_velocidad_4)
# Out:
# -56.54906300557913 353.83790479342895

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_4, (diferencia_longitudes_o_4*300000000)/np.array(long_o_4), marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_4, (diferencia_longitudes_fe_4*300000000)/(np.array(long_fe_4)), marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

#ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 4')

plt.show()

fig.savefig('Shift_4.png')

# %% [markdown]
# # Toma 5

# %% [markdown]
# ### $\theta = 0.224688$ ancho (207,211)

# %%
pixeles_fe_5 = [centroide([431,432,433],[22198,21242,21168]),centroide([771,772,773],[21684,21779,23075]),centroide([995,996,997],[19853,19719,21657]),centroide([1116,1117,1119],[17348,16273,18429]),centroide([1149,1150,1151],[19308,19002,19678])]
long_fe_5 = [6280.622, 6290.974 , 
           6297.799 , 6301.508, 6302.499]

pixeles_o_5 = [centroide([374,375,376],[26512,25900,26401]),centroide([406,408,409],[25588,25076,26271]),centroide([424,425,426],[25060,25053,25720]),centroide([449,450,451],[27271,26166,27283]),centroide([475,476,477],[26404,26296,27707]),centroide([500,501,502],[24532,24138,24871]),centroide([664,665,666],[28390,27877,28251]),centroide([718,719,721],[28019,27268,28491]),centroide([744,746,747],[28253,26458,26616]),centroide([809,810,811],[26850,26112,27061]),centroide([835,836,837],[25627,25048,25777]),centroide([908,909,910],[26327,25366,26240]),centroide([934,935,936],[25529,24842,26669]),centroide([1015,1016,1017],[27064,25533,25411]),centroide([1041,1042,1043],[25454,24142,24932]),centroide([1132,1133,1134],[26588,25857,26502]),centroide([1157,1158,1159],[25971,25699,25945])]
long_o_5 = [6278.878, 6279.896, 6280.393, 
          6281.178, 6281.956, 6282.726, 
           6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]
'''

pixeles_fe_5 = [centroide([431,432,433],[22198,21242,21168]),centroide([771,772,773],[21684,21779,23075]),centroide([995,996,997],[19853,19719,21657]),centroide([1116,1117,1119],[17348,16273,18429]),centroide([1149,1150,1151],[19308,19002,19678])]
long_fe_5 = [6280.622, 6290.974 , 
           6297.799 , 6301.508, 6302.499]

pixeles_o_5 = [centroide([424,425,426],[25060,25053,25720]),centroide([449,450,451],[27271,26166,27283]),centroide([475,476,477],[26404,26296,27707]),centroide([500,501,502],[24532,24138,24871]),centroide([664,665,666],[28390,27877,28251]),centroide([718,719,721],[28019,27268,28491]),centroide([744,746,747],[28253,26458,26616]),centroide([809,810,811],[26850,26112,27061]),centroide([835,836,837],[25627,25048,25777]),centroide([908,909,910],[26327,25366,26240]),centroide([934,935,936],[25529,24842,26669]),centroide([1015,1016,1017],[27064,25533,25411]),centroide([1041,1042,1043],[25454,24142,24932]),centroide([1132,1133,1134],[26588,25857,26502]),centroide([1157,1158,1159],[25971,25699,25945])]
long_o_5 = [6280.393, 
          6281.178, 6281.956, 6282.726, 
           6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

'''
# Out:
# '\n\npixeles_fe_5 = [centroide([431,432,433],[22198,21242,21168]),centroide([771,772,773],[21684,21779,23075]),centroide([995,996,997],[19853,19719,21657]),centroide([1116,1117,1119],[17348,16273,18429]),centroide([1149,1150,1151],[19308,19002,19678])]\nlong_fe_5 = [6280.622, 6290.974 , \n           6297.799 , 6301.508, 6302.499]\n\npixeles_o_5 = [centroide([424,425,426],[25060,25053,25720]),centroide([449,450,451],[27271,26166,27283]),centroide([475,476,477],[26404,26296,27707]),centroide([500,501,502],[24532,24138,24871]),centroide([664,665,666],[28390,27877,28251]),centroide([718,719,721],[28019,27268,28491]),centroide([744,746,747],[28253,26458,26616]),centroide([809,810,811],[26850,26112,27061]),centroide([835,836,837],[25627,25048,25777]),centroide([908,909,910],[26327,25366,26240]),centroide([934,935,936],[25529,24842,26669]),centroide([1015,1016,1017],[27064,25533,25411]),centroide([1041,1042,1043],[25454,24142,24932]),centroide([1132,1133,1134],[26588,25857,26502]),centroide
# ...

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_5, long_o_5, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_5, long_fe_5, marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 5')

plt.show()

fig.savefig('Calibre_5.png')

# %%
popt_5, pcov_5 = curve_fit(func, pixeles_o_5, long_o_5)


longitudes_o_funcion_5 = func(np.array(pixeles_o_5),popt_5[0],popt_5[1],popt_5[2])


diferencia_longitudes_o_5 = longitudes_o_funcion_5 - np.array(long_o_5)

diferencia_longitudes_o_5, long_o_5, pixeles_o_5 = limpia(diferencia_longitudes_o_5,long_o_5,pixeles_o_5,-200,200)


popt_5, pcov_5 = curve_fit(func, pixeles_o_5, long_o_5)

longitudes_fe_funcion_5 = func(np.array(pixeles_fe_5),popt_5[0],popt_5[1],popt_5[2])

diferencia_longitudes_fe_5 = longitudes_fe_funcion_5 - np.array(long_fe_5)

# %%
error_fe_5 = error_func(np.array(pixeles_fe_5),pcov_5[0][0],pcov_5[1][1],pcov_5[2][2])
error_o_5 = error_func(np.array(pixeles_o_5),pcov_5[0][0],pcov_5[1][1],pcov_5[2][2])

# %% [markdown]
# ### Resultados velocidad toma 5

# %%
velocidades_5 = (diferencia_longitudes_fe_5*300000000)/(np.array(long_fe_5))
error_velocidades_5 = error_vel(velocidades_5,error_fe_5,np.array(long_fe_5))

velocidad_5 = np.mean(velocidades_5)
error_velocidad_5 = error_vel_promedio(len(error_velocidades_5),error_velocidades_5)
print(velocidad_5, error_velocidad_5)
# Out:
# 757.7269615492673 479.7328112847773

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_5, (diferencia_longitudes_o_5*300000000)/np.array(long_o_5), marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_5, (diferencia_longitudes_fe_5*300000000)/(np.array(long_fe_5)), marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

#ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 5')

plt.show()

fig.savefig('Shift_5.png')

# %% [markdown]
# # Toma 6

# %% [markdown]
# ### $\theta = 0.224688$ ancho (219,225)

# %% [markdown]
# ###

# %%
'''
pixeles_fe_6 = [centroide([441,443,444],[22808,21736,22788]),centroide([780,781,782],[22627,22046,22334]),centroide([877,878,879],[28287,28015,28313]),centroide([1004,1006,1007],[21204,20753,21833]),centroide([1126,1127,1128],[17522,16757,17308]),centroide([1159,1160,1161],[19803,19448,20161])]
long_fe_6 = [6280.622, 6290.974 ,6293.933, 
           6297.799 , 6301.508, 6302.499]
'''
pixeles_fe_6 = [centroide([441,443,444],[22808,21736,22788]),centroide([780,781,782],[22627,22046,22334]),centroide([1004,1006,1007],[21204,20753,21833]),centroide([1126,1127,1128],[17522,16757,17308]),centroide([1159,1160,1161],[19803,19448,20161])]
long_fe_6 = [6280.622, 6290.974 , 
           6297.799 , 6301.508, 6302.499]
           
pixeles_o_6 = [centroide([358,359,360],[18748,18108,19005]),centroide([384,385,386],[25598,24959,25060]),centroide([392,393,394],[24467,24289,25590]),centroide([416,417,418],[24447,24056,24264]),centroide([434,435,436],[24150,23908,24525]),centroide([459,460,461],[26145,25771,25770]),centroide([485,486,487],[25630,25171,26095]),centroide([510,511,512],[24162,23840,24130]),centroide([545,546,547],[27269,26989,27390]),centroide([568,569,570],[29067,28498,28597]),centroide([674,675,676],[27599,27384,27414]),centroide([729,730,731],[26865,26556,27541]),centroide([756,757,758],[25827,25747,26767]),centroide([819,820,821],[25616,5373,25764]),centroide([845,846,847],[24198,24084,24729]),centroide([918,919,920],[25156,25039,25334]),centroide([944,945,946],[24692,24458,25392]),centroide([1025,1026,1027],[25333,24913,24839]),centroide([1050,1052,1053],[24837,23496,23843]),centroide([1142,1143,1144],[25292,24887,25175]),centroide([1167,1168,1169],[24834,24788,25162])]
long_o_6 = [6278.073, 
          6278.878, 6279.101, 6279.896, 6280.393, 
          6281.178, 6281.956, 6282.726, 6283.796, 
          6284.536, 6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.5)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_6, long_o_6, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_6, long_fe_6, marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 6')

plt.show()

fig.savefig('Calibre_6.png')

# %%
popt_6, pcov_6 = curve_fit(func, pixeles_o_6, long_o_6)




longitudes_o_funcion_6 = func(np.array(pixeles_o_6),popt_6[0],popt_6[1],popt_6[2])

diferencia_longitudes_o_6 = longitudes_o_funcion_6 - np.array(long_o_6)

diferencia_longitudes_o_6, long_o_6, pixeles_o_6 = limpia(diferencia_longitudes_o_6,long_o_6,pixeles_o_6,-200,200)


popt_6, pcov_6 = curve_fit(func, pixeles_o_6, long_o_6)

longitudes_fe_funcion_6 = func(np.array(pixeles_fe_6),popt_6[0],popt_6[1],popt_6[2])
diferencia_longitudes_fe_6 = longitudes_fe_funcion_6 - np.array(long_fe_6)

# %%
error_o_6 = error_func(np.array(pixeles_o_6),pcov_6[0][0],pcov_6[1][1],pcov_6[2][2])
error_fe_6 = error_func(np.array(pixeles_fe_6),pcov_6[0][0],pcov_6[1][1],pcov_6[2][2])

# %% [markdown]
# ### Resultados velocidad toma 6

# %%
velocidades_6 = (diferencia_longitudes_fe_6*300000000)/(np.array(long_fe_6))
error_velocidades_6 = error_vel(velocidades_6,error_fe_6,np.array(long_fe_6))

velocidad_6 = np.mean(velocidades_6)
error_velocidad_6 = error_vel_promedio(len(error_velocidades_6),error_velocidades_6)
print(velocidad_6, error_velocidad_6)
# Out:
# 673.8734491525897 1770.615539712048

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


#ax.scatter(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', s=0.6)
#ax.scatter(longitudes_o, reduced_width_o, label = 'O', color = 'b', s=1)

ax.scatter(pixeles_o_6, (diferencia_longitudes_o_6*300000000)/np.array(long_o_6), marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_6, (diferencia_longitudes_fe_6*300000000)/(np.array(long_fe_6)), marker = 'o', label = 'Fe', color = 'r', s = 10)

#ax.plot(longitudes_fe, reduced_width_fe, label = 'Fe', color = 'r', marker = 'o', linewidth=1, markersize=1)
#ax.plot(longitudes_o, reduced_width_o, label = 'O', color = 'b', marker = 'o', linewidth=1, markersize=1)

#ax.set_yticks(np.arange(6270, 6310, 6))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 6')

plt.show()

fig.savefig('Shift_6.png')

# %% [markdown]
# ## Ensayo toma 7

# %% [markdown]
# ### $\theta = 0.1872$, ancho = 219 a 224

# %%
'''
pixeles_o_7 = [centroide([311,312,313],[23764,23004,23425]),centroide([359,360,361],[16407,16018,16728]),centroide([385,386,388],[24708,23788,24925]),centroide([393,394,395],[23195,22972,24470]),centroide([435,436,437],[23304,22742,23460]),centroide([460,461,462],[25288,23347,24488]),centroide([486,487,488],[24257,23989,24812]),centroide([570,571,572],[28270,28008,28012]),centroide([675,676,678],[26772,26150,26790]),centroide([820,821,822],[24270,23533,24275]),centroide([846,847,848],[22702,22370,23069]),centroide([919,920,921],[23402,22938,23459]),centroide([945,946,947],[22627,22413,23623]),centroide([1027,1028,1029],[22755,22790,23933]),centroide([1052,1053,1054],[22090,21270,21996]),centroide([1143,1144,1145],[23531,23049,23751]),centroide([1168,1169,1170],[23100,22859,23300])]

long_o_7 = [6276.59,  6278.073, 
          6278.878, 6279.101, 6280.393, 
          6281.178, 6281.956,  
          6284.536, 6287.749, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

pixeles_fe_7 = [centroide([443,444,446],[21702,21605,23832]),centroide([781,782,783],[22016,21379,21413]),centroide([877,878,879],[27683,27292,27403]),centroide([1005,1007,1008],[20418,19539,21921]),centroide([1127,1128,1129],[16627,16113,16536]),centroide([1160,1161,1162],[18977,18594,19230])]

long_fe_7 = [6280.622, 6290.974 ,6293.933, 
           6297.799 , 6301.508, 6302.499]
'''
# Out:
# '\npixeles_o_7 = [centroide([311,312,313],[23764,23004,23425]),centroide([359,360,361],[16407,16018,16728]),centroide([385,386,388],[24708,23788,24925]),centroide([393,394,395],[23195,22972,24470]),centroide([435,436,437],[23304,22742,23460]),centroide([460,461,462],[25288,23347,24488]),centroide([486,487,488],[24257,23989,24812]),centroide([570,571,572],[28270,28008,28012]),centroide([675,676,678],[26772,26150,26790]),centroide([820,821,822],[24270,23533,24275]),centroide([846,847,848],[22702,22370,23069]),centroide([919,920,921],[23402,22938,23459]),centroide([945,946,947],[22627,22413,23623]),centroide([1027,1028,1029],[22755,22790,23933]),centroide([1052,1053,1054],[22090,21270,21996]),centroide([1143,1144,1145],[23531,23049,23751]),centroide([1168,1169,1170],[23100,22859,23300])]\n\nlong_o_7 = [6276.59,  6278.073, \n          6278.878, 6279.101, 6280.393, \n          6281.178, 6281.956,  \n          6284.536, 6287.749, \n          6292.162, 6292.958, 6295.178, 6295.960,\n       
# ...

# %%
pixeles_o_7 = [centroide([311,312,313],[23764,23004,23425]),centroide([359,360,361],[16407,16018,16728]),centroide([385,386,388],[24708,23788,24925]),centroide([393,394,395],[23195,22972,24470]),centroide([435,436,437],[23304,22742,23460]),centroide([460,461,462],[25288,23347,24488]),centroide([486,487,488],[24257,23989,24812]),centroide([570,571,572],[28270,28008,28012]),centroide([675,676,678],[26772,26150,26790]),centroide([820,821,822],[24270,23533,24275]),centroide([846,847,848],[22702,22370,23069]),centroide([919,920,921],[23402,22938,23459]),centroide([945,946,947],[22627,22413,23623]),centroide([1027,1028,1029],[22755,22790,23933]),centroide([1052,1053,1054],[22090,21270,21996]),centroide([1143,1144,1145],[23531,23049,23751]),centroide([1168,1169,1170],[23100,22859,23300])]

long_o_7 = [6276.59,  6278.073, 
          6278.878, 6279.101, 6280.393, 
          6281.178, 6281.956,  
          6284.536, 6287.749, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

pixeles_fe_7 = [centroide([443,444,446],[21702,21605,23832]),centroide([781,782,783],[22016,21379,21413]),centroide([1005,1007,1008],[20418,19539,21921]),centroide([1127,1128,1129],[16627,16113,16536]),centroide([1160,1161,1162],[18977,18594,19230])]

long_fe_7 = [6280.622, 6290.974, 
           6297.799 , 6301.508, 6302.499]

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


ax.scatter(pixeles_o_7, long_o_7, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_7, long_fe_7, marker = 'o', label = 'Fe', color = 'r', s = 10)


ax.set_yticks(np.arange(6270, 6310, 5))


ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 7')

plt.show()

fig.savefig('Calibre_7.png')

# %%
popt_7, pcov_7 = curve_fit(func, pixeles_o_7, long_o_7)



longitudes_o_funcion_7 = func(np.array(pixeles_o_7),popt_7[0],popt_7[1],popt_7[2])


diferencia_longitudes_o_7 = longitudes_o_funcion_7 - np.array(long_o_7)

diferencia_longitudes_o_7, long_o_7, pixeles_o_7 = limpia(diferencia_longitudes_o_7,long_o_7,pixeles_o_7,-200,200)

popt_7, pcov_7 = curve_fit(func, pixeles_o_7, long_o_7)

longitudes_fe_funcion_7 = func(np.array(pixeles_fe_7),popt_7[0],popt_7[1],popt_7[2])
diferencia_longitudes_fe_7 = longitudes_fe_funcion_7 - np.array(long_fe_7)

# %%
error_fe_7= error_func(np.array(pixeles_fe_7),pcov_7[0][0],pcov_7[1][1],pcov_7[2][2])
error_o_7 = error_func(np.array(pixeles_o_7),pcov_7[0][0],pcov_7[1][1],pcov_7[2][2])

# %%
velocidades_7 = (diferencia_longitudes_fe_7*300000000)/(np.array(long_fe_7))
velocidad_7 = np.mean(velocidades_7)

error_velocidades_7 = error_vel(velocidades_7,error_fe_7,np.array(long_fe_7))
error_velocidad_7 = error_vel_promedio(len(error_velocidades_7),error_velocidades_7)
print(velocidad_7, error_velocidad_7)
# Out:
# 514.5806438046167 393.2666307257825

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)



ax.scatter(pixeles_o_7, (diferencia_longitudes_o_7/long_o_7)*300000000, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_7, (diferencia_longitudes_fe_7/long_fe_7)*300000000, marker = 'o', label = 'Fe', color = 'r', s = 10)


ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 7')

plt.show()

fig.savefig('Shift_7.png')

# %% [markdown]
# ## Ensayo toma 8

# %% [markdown]
# ### $\theta = 0.1872$, ancho = 220 a 225

# %%
'''

pixeles_fe_8 = [centroide([442,443,444],[22195,22001,22587]),  centroide([877,878,879],[27505,27408,27421]), centroide([1005,1006,1007],[21220,21117,20616]), 
                centroide([1127,1128,1129],[17271,16882,17390]), centroide([1160,1161,1162],[19219,18972,19236])]

long_fe_8 = [6280.622, 6293.933, 
           6297.799 , 6301.508, 6302.499]

long_o_8 = [  
          6278.878,
          6281.178, 6281.956, 6282.726, 6283.796, 
          6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

pixeles_o_8 = [centroide([386,387,388],[19708,19264,19745]), 
              centroide([460,461,462],[21598,20842,21203]), 
               centroide([485,487,488],[21762,20798,21332]), centroide([511,512,513],[19263,18811,19644]), centroide([546,547,548],[23401,22715,23472]), 
               centroide([675,676,677],[23438,22779,22608]), centroide([730,731,732],[23422,22562,23922]),centroide([756,757,758],[21956,21211,21253]),centroide([819,821,822],[21766,20583,21108]), 
               centroide([845,846,848],[20182,19875,20211]), centroide([919,920,921],[20803,20314,20825]), centroide([944,946,947],[20812,19642,21211]), centroide([1026,1027,1029],[20533,20142,21387]), 
               centroide([1052,1053,1054],[18833,18279,18965]), centroide([1143,1144,1145],[20942,20639,21054]), centroide([1168,1169,1170],[20492,20170,20816])]
'''

pixeles_fe_8 = [ 
                centroide([1127,1128,1129],[17271,16882,17390]), centroide([1160,1161,1162],[19219,18972,19236])]

long_fe_8 = [6301.508, 6302.499]

long_o_8 = [  
          6278.878,
          6281.178, 6281.956, 6282.726, 6283.796, 
          6287.749, 6289.398, 6290.221, 
          6292.162, 6292.958, 6295.178, 6295.960,
            6298.457, 6299.228, 6302.000, 6302.764]

pixeles_o_8 = [centroide([386,387,388],[19708,19264,19745]), 
              centroide([460,461,462],[21598,20842,21203]), 
               centroide([485,487,488],[21762,20798,21332]), centroide([511,512,513],[19263,18811,19644]), centroide([546,547,548],[23401,22715,23472]), 
               centroide([675,676,677],[23438,22779,22608]), centroide([730,731,732],[23422,22562,23922]),centroide([756,757,758],[21956,21211,21253]),centroide([819,821,822],[21766,20583,21108]), 
               centroide([845,846,848],[20182,19875,20211]), centroide([919,920,921],[20803,20314,20825]), centroide([944,946,947],[20812,19642,21211]), centroide([1026,1027,1029],[20533,20142,21387]), 
               centroide([1052,1053,1054],[18833,18279,18965]), centroide([1143,1144,1145],[20942,20639,21054]), centroide([1168,1169,1170],[20492,20170,20816])]

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


ax.scatter(pixeles_o_8, long_o_8, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_8, long_fe_8, marker = 'o', label = 'Fe', color = 'r', s = 10)


ax.set_yticks(np.arange(6270, 6310, 5))
#ax.ticklabel_format(axis='x', style='scientific',scilimits=(0,0), useMathText=True)

ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Curva de calibracion toma 8')

plt.show()

fig.savefig('Calibre_8.png')

# %%
popt_8, pcov_8 = curve_fit(func, pixeles_o_8, long_o_8)



longitudes_o_funcion_8 = func(np.array(pixeles_o_8),popt_8[0],popt_8[1],popt_8[2])


diferencia_longitudes_o_8 = longitudes_o_funcion_8 - np.array(long_o_8)


diferencia_longitudes_o_8, long_o_8, pixeles_o_8 = limpia(diferencia_longitudes_o_8,long_o_8,pixeles_o_8,-200,200)

popt_8, pcov_8 = curve_fit(func, pixeles_o_8, long_o_8)
longitudes_fe_funcion_8 = func(np.array(pixeles_fe_8),popt_8[0],popt_8[1],popt_8[2])
diferencia_longitudes_fe_8 = longitudes_fe_funcion_8 - np.array(long_fe_8)

# %%
error_fe_8= error_func(np.array(pixeles_fe_8),pcov_8[0][0],pcov_8[1][1],pcov_8[2][2])
error_o_8 = error_func(np.array(pixeles_o_8),pcov_8[0][0],pcov_8[1][1],pcov_8[2][2])

# %% [markdown]
# ### Velocidad toma 8

# %%
velocidades_8 = (diferencia_longitudes_fe_8*300000000)/(np.array(long_fe_8))
velocidad_8 = np.mean(np.array(velocidades_8))

error_velocidades_8 = error_vel(velocidades_8,error_fe_8,np.array(long_fe_8))
error_velocidad_8 = error_vel_promedio(len(error_velocidades_8),error_velocidades_8)
print(velocidad_8, error_velocidad_8)
# Out:
# 779.138542046661 3475.142205099404

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)



ax.scatter(pixeles_o_8, (diferencia_longitudes_o_8/long_o_8)*300000000, marker = 'x', label = 'O', color = 'black', s = 10)
ax.scatter(pixeles_fe_8, (diferencia_longitudes_fe_8/long_fe_8)*300000000, marker = 'o', label = 'Fe', color = 'r', s = 10)


ax.set_ylabel(r'Longitud de onda (Angstrongs)')
ax.set_xlabel('Pixeles')
ax.legend()
ax.set_title('Shift toma 8')

plt.show()

fig.savefig('Shift_8.png')

# %% [markdown]
# # Análisis velocidad

# %%
def solar_hour_angle(hour):
    deg = 15*(hour-12)
    return deg*np.pi/180

# %%
'''
vel_finales = [velocidad,velocidad_2,velocidad_3,velocidad_4,velocidad_5,velocidad_6,velocidad_7,velocidad_8]
error_vel_finales = [error_velocidad_1,error_velocidad_2,error_velocidad_3,error_velocidad_4,error_velocidad_5,error_velocidad_6,error_velocidad_7,error_velocidad_8]

horas = np.array([8.38, 9.13, 9.97, 10.67, 14.83, 16.13, 16.82, 17.72])


vel_finales = [velocidad,velocidad_2,velocidad_3,velocidad_4,velocidad_5,velocidad_7]
error_vel_finales = [error_velocidad_1,error_velocidad_2,error_velocidad_3,error_velocidad_4,error_velocidad_5,error_velocidad_7]

horas = np.array([8.38, 9.13, 9.97, 10.67, 14.83,  16.82])
'''



vel_finales = [velocidad,velocidad_2,velocidad_3,velocidad_4,velocidad_5,velocidad_6,velocidad_7]
error_vel_finales = [error_velocidad_1,error_velocidad_2,error_velocidad_3,error_velocidad_4,error_velocidad_5,error_velocidad_6,error_velocidad_7]


horas = np.array([8.38, 9.13, 9.97, 10.67, 14.83, 16.13, 16.82])


angulo_solar = np.sin(solar_hour_angle(horas))

# %%
def func_2(x, a, b):
    return a*x + b

# %%
popt_final, pcov_final = curve_fit(func_2, angulo_solar, vel_finales, sigma = error_vel_finales, absolute_sigma = True)
#popt_final, pcov_final = curve_fit(func_2, angulo_solar, vel_finales)
print(popt_final[0],popt_final[1])
print(np.sqrt(pcov_final[0][0]),pcov_final[1][1])
# Out:
# 426.28138270304527 220.3203506558007
# 222.33681129821417 22492.943934038656

# %%
x_data = np.linspace(-1,1,100)
y_data = func_2(x_data,popt_final[0],popt_final[1])

# %%
fig = plt.figure(dpi=200)
ax = fig.add_subplot(1,1,1)


ax.scatter(angulo_solar, vel_finales, marker = 'o', color = 'black', s = 10)
ax.errorbar(angulo_solar, vel_finales, xerr = None, yerr = error_vel_finales, ls='none',color = 'k')

ax.plot(x_data, y_data, color = 'k', label = r'y = {:.0f}x + {:.0f}'.format(popt_final[0],popt_final[1]))

ax.legend()

ax.set_ylabel(r'Velocidad radial ($\frac{m}{s}$)')
ax.set_xlabel('seno del ángulo solar')
ax.set_title('Velocidades radiales medidas')

plt.show()

fig.savefig('Radial_vel.png')
